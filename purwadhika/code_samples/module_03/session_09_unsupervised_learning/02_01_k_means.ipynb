# %% [markdown]
# # Module 03
#
# ## Session 09 Unsipervised Learning

# %% [markdown]
# # K-Means

# %% [markdown]
# Analyze generated data from make_blobs
# * set 3 main spot (random_state = 42)
# * plot the data using scatter plot
# * determine the optimal number of cluster based on your observation
# * fit k-means and plot the custering result in scatter plot. is it 3 cluster?

# %% [markdown]
# # Library

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
X,y = make_blobs(random_state=42)

# %% [markdown]
# # Visualization Data

# %%
sns.scatterplot(x=X[:,0], y=X[:,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # K-Means

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans.labels_
# Out:
# array([1, 0, 2, 0, 1, 0, 2, 0, 0, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1,
#        1, 2, 2, 2, 0, 1, 1, 1, 1, 0, 0, 1, 2, 2, 2, 2, 0, 0, 1, 2, 0, 2,
#        2, 0, 1, 1, 1, 0, 0, 0, 2, 1, 1, 1, 2, 2, 0, 2, 1, 0, 1, 0, 1, 1,
#        0, 1, 0, 0, 0, 1, 1, 2, 0, 1, 0, 1, 0, 0, 2, 0, 2, 1, 2, 2, 2, 0,
#        2, 0, 0, 0, 2, 0, 2, 2, 2, 0, 1, 2], dtype=int32)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=kmeans.labels_)
# Out:
# <AxesSubplot:>
